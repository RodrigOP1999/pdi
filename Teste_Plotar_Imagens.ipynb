# %%
# !pip install gdal
# !pip install rasterio
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.9/20.9 MB 23.2 MB/s eta 0:00:00
# ...

# %%
# !pip install spectral
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.9/212.9 KB 5.3 MB/s eta 0:00:00
# ...

# %%
import tifffile as tif
import matplotlib.pyplot as plt
from spectral import imshow

# %%
img = tif.imread('/content/Mesclado_CBERS_20182114.tif')

# %%
img.shape
# Out:
# (697, 1340, 3)

# %%
plt.imshow(img)

# %%
plt.imshow(img[:,:,0], cmap='Greys_r')

# %%
imshow(img)
# Out:
# ImageView object:
#   Display bands       :  [0, 1, 2]
#   Interpolation       :  <default>
#   RGB data limits     :
#     R: [5.0, 255.0]
#     G: [13.0, 255.0]
#     B: [18.0, 255.0]

# %%
imshow(img, (2,1,0))
# Out:
# ImageView object:
#   Display bands       :  (2, 1, 0)
#   Interpolation       :  <default>
#   RGB data limits     :
#     R: [18.0, 255.0]
#     G: [13.0, 255.0]
#     B: [5.0, 255.0]

# %%
imshow(img, (0,2,1))
# Out:
# ImageView object:
#   Display bands       :  (0, 2, 1)
#   Interpolation       :  <default>
#   RGB data limits     :
#     R: [5.0, 255.0]
#     G: [18.0, 255.0]
#     B: [13.0, 255.0]
